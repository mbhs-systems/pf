# %%
import sys; sys.path.append("..")

import numpy as np
import logging

from numpy import pi
from dedalus.extras import flow_tools

import dedaLES.dedaLES as dedaLES

import matplotlib.pyplot as plt
from dedalus.extras.plot_tools import plot_bot_3d


# from dedaLES import mpiprint

logger = logging.getLogger(__name__)

# Parameters
nx = ny = nz = 32
Lx = Ly = Lz = 2*pi

# Homoegneous Navier-Stokes equations
closure = None
model = dedaLES.NavierStokesTriplyPeriodicFlow(nx=nx, ny=ny, nz=nz, Lx=Lx, Ly=Ly, Lz=Lz,
                                               ν=1.0, closure=closure)
model.build_solver()

# Random initial condition. Re_k = u k / ν => u ~ ν * Re_k / k
Re = 1000.0 # Re at grid scale
u0 = Re/nx
model.u['g'] = u0 * dedaLES.random_noise(model.domain, seed=23)
model.v['g'] = u0 * dedaLES.random_noise(model.domain, seed=42)

model.u['g'] = model.u['g'] - np.mean(model.u['g'])
model.v['g'] = model.v['g'] - np.mean(model.v['g'])

# Diagnose w from continuity
ux = model.domain.new_field()
vy = model.domain.new_field()
wz = model.domain.new_field()
model.u.differentiate('x', out=ux)
model.v.differentiate('y', out=vy)
model.w.differentiate('z', out=wz)

wz['g'] = - ux['g'] - vy['g']
wz.integrate('z', out=model.w)

# Plot energy spectra...

# Run the simulation
max_u = np.max(model.u['g'])
dt = 0.1 * 2*pi/(max_u*nx) # grid-scale turbulence time-scale = 1/(u*k)
cadence = 10

flow = flow_tools.GlobalFlowProperty(model.solver, cadence=cadence)
flow.add_property("sqrt(u*u + v*v + w*w) / ν", name='Re')

def average_Re(model): return flow.volume_average('Re')
def max_Re(model): return flow.max('Re')

model.add_log_tasks(avg_Re=average_Re, max_Re=max_Re)
model.stop_at(sim_time=np.inf, wall_time=np.inf, iteration=100)

# start_time = time.time()
# while model.solver.ok:
#     dt = cfl.compute_dt()
#     solver.step(dt)
#     if model.solver.iteration % 10 == 0:
#         plot_bot_3d(model.solver.state['p'], normal_axis=1, normal_index=1)

# plot_bot_3d(model.solver.state['p'], normal_axis=1, normal_index=1)
# plt.show()

# initial_p = model.solver.state['p']
# 
model.stop_at(sim_time=np.inf, wall_time=np.inf, iteration=100)
model.run(dt=dt, log_cadence=cadence)

plot_bot_3d(np.real(model.p), normal_axis=1, normal_index=1)
plt.show()
# Out:
# 2019-02-13 14:53:05,319 pencil 0/1 INFO :: Building pencil matrix 1/496 (~0%) Elapsed: 0s, Remaining: 6s, Rate: 7.9e+01/s
# 2019-02-13 14:53:05,932 pencil 0/1 INFO :: Building pencil matrix 50/496 (~10%) Elapsed: 1s, Remaining: 6s, Rate: 8.0e+01/s
# 2019-02-13 14:53:06,557 pencil 0/1 INFO :: Building pencil matrix 100/496 (~20%) Elapsed: 1s, Remaining: 5s, Rate: 8.0e+01/s
# 2019-02-13 14:53:07,173 pencil 0/1 INFO :: Building pencil matrix 150/496 (~30%) Elapsed: 2s, Remaining: 4s, Rate: 8.0e+01/s
# 2019-02-13 14:53:07,783 pencil 0/1 INFO :: Building pencil matrix 200/496 (~40%) Elapsed: 2s, Remaining: 4s, Rate: 8.1e+01/s
dedaLES.dedaLES.flows 0/1 INFO :: max_Re: 155.86821241964947
# 2019-02-13 14:53:23,524 dedaLES.dedaLES.flows 0/1 INFO :: Iteration: 91, Time: 1.490954e-02, dt: 1.638411e-04
# 2019-02-13 14:53:23,527 dedaLES.dedaLES.flows 0/1 INFO :: avg_Re: 41.854493165708064
# 2019-02-13 14:53:23,529 dedaLES.dedaLES.flows 0/1 INFO :: max_Re: 134.6167265166058
# 2019-02-13 14:53:24,661 solvers 0/1 INFO :: Stop iteration reached.
# 2019-02-13 14:53:24,662 dedaLES.dedaLES.flows 0/1 INFO :: Iterations: 100
# 2019-02-13 14:53:24,662 dedaLES.dedaLES.flows 0/1 INFO :: Sim end time: 0.016384
# 2019-02-13 14:53:24,662 dedaLES.dedaLES.flows 0/1 INFO :: Run time: 13.11 sec
# 2019-02-13 14:53:24,663 dedaLES.dedaLES.flows 0/1 INFO :: Run time: 0.003640 cpu-hr
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-4bba491e4294> in <module>
#      79
#      80
# ---> 81 plot_bot_3d(model.solver.state['p'], normal_axis=1, normal_index=1)
#      82 plt.show()
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/dedalus/extras/plot_tools.py in plot_bot_3d(dset, normal_axis, normal_index, transpose, **kw)
#     230     data_slices[normal_axis] = normal_index
#     231
# --> 232     return plot_bot(dset, image_axes, tuple(data_slices), **kw)
#     233
#     234
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/dedalus/extras/plot_tools.py in plot_bot(dset, image_axes, data_slices, image_scales, clim, even_scale, cmap, axes, figkw, title, func)
#     130     # Colorbar
#     131     cbar = plt.colorbar(plot, cax=caxes, orientation='horizontal',
# --> 132         ticks=ticker.MaxNLocator(nbins=5))
#     133     cbar.outline.set_visible(False)
#     134     caxes.xaxis.set_ticks_position('top')
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2098         ax = gca()
#    2099
# -> 2100     ret = gcf().colorbar(mappable, cax = cax, ax=ax, **kw)
#    2101     return ret
#    2102 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1565         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1566     else:
# -> 1567         cb = Colorbar(cax, mappable, **kwargs)
#    1568
#    1569     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1096                 kw['alpha'] = mappable.get_alpha()
#    1097
# -> 1098             ColorbarBase.__init__(self, ax, **kw)
#    1099
#    1100     def on_mappable_changed(self, mappable):
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     412             self.formatter = format  # Assume it is a Formatter
#     413         # The rest is in a method so we can recalculate when clim changes.
# --> 414         self.draw_all()
#     415
#     416     def _extend_lower(self):
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in draw_all(self)
#     436         # sets self._boundaries and self._values in real data units.
#     437         # takes into account extend values:
# --> 438         self._process_values()
#     439         # sets self.vmin and vmax in data units, but just for
#     440         # the part of the colorbar that is not part of the extend
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in _process_values(self, b)
#     842                 self.norm.vmin,
#     843                 self.norm.vmax,
# --> 844                 expander=0.1)
#     845
#     846             b = self.norm.inverse(self._uniform_y(self.cmap.N + 1))
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/transforms.py in nonsingular(vmin, vmax, expander, tiny, increasing)
#    2891
#    2892     swapped = False
# -> 2893     if vmax < vmin:
#    2894         vmin, vmax = vmax, vmin
#    2895         swapped = True
#
# TypeError: '<' not supported between instances of 'complex' and 'complex'
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f97906b62f0> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#    1917                 offsets = np.column_stack([xs, ys])
#    1918
# -> 1919         self.update_scalarmappable()
#    1920
#    1921         if not transform.is_affine:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/collections.py in update_scalarmappable(self)
#     777             return
#     778         if self._is_filled:
# --> 779             self._facecolors = self.to_rgba(self._A, self._alpha)
#     780         elif self._is_stroked:
#     781             self._edgecolors = self.to_rgba(self._A, self._alpha)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     287         if norm:
#     288             x = self.norm(x)
# --> 289         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     290         return rgba
#     291
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     545
#     546         rgba = np.empty(shape=xa.shape + (4,), dtype=lut.dtype)
# --> 547         lut.take(xa, axis=0, mode='clip', out=rgba)
#     548         if vtype == 'scalar':
#     549             rgba = tuple(rgba[0, :])
#
# TypeError: Cannot cast array data from dtype('complex128') to dtype('int64') according to the rule 'safe'

# %%
# while model.solver.ok:
# #     dt = cfl.compute_dt()
#     model.solver.step(dt)
#     if model.solver.iteration % 10 == 0:
#         plot_bot_3d(model.solver.state['p'], normal_axis=1, normal_index=1)

# %%
# plot_bot_3d(np.real(initial_p), normal_axis=1, normal_index=1)
# plt.show()

# plot_bot_3d(np.real(model.solver.state['p']), normal_axis=1, normal_index=1)
# plt.show()

# %%
plot_bot_3d(model.u, normal_axis=1, normal_index=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-4670826d40a3> in <module>
# ----> 1 plot_bot_3d(model.u, normal_axis=1, normal_index=1)
#       2 plt.show()
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/dedalus/extras/plot_tools.py in plot_bot_3d(dset, normal_axis, normal_index, transpose, **kw)
#     230     data_slices[normal_axis] = normal_index
#     231
# --> 232     return plot_bot(dset, image_axes, tuple(data_slices), **kw)
#     233
#     234
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/dedalus/extras/plot_tools.py in plot_bot(dset, image_axes, data_slices, image_scales, clim, even_scale, cmap, axes, figkw, title, func)
#     130     # Colorbar
#     131     cbar = plt.colorbar(plot, cax=caxes, orientation='horizontal',
# --> 132         ticks=ticker.MaxNLocator(nbins=5))
#     133     cbar.outline.set_visible(False)
#     134     caxes.xaxis.set_ticks_position('top')
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2098         ax = gca()
#    2099
# -> 2100     ret = gcf().colorbar(mappable, cax = cax, ax=ax, **kw)
#    2101     return ret
#    2102 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1565         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1566     else:
# -> 1567         cb = Colorbar(cax, mappable, **kwargs)
#    1568
#    1569     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1096                 kw['alpha'] = mappable.get_alpha()
#    1097
# -> 1098             ColorbarBase.__init__(self, ax, **kw)
#    1099
#    1100     def on_mappable_changed(self, mappable):
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     412             self.formatter = format  # Assume it is a Formatter
#     413         # The rest is in a method so we can recalculate when clim changes.
# --> 414         self.draw_all()
#     415
#     416     def _extend_lower(self):
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in draw_all(self)
#     436         # sets self._boundaries and self._values in real data units.
#     437         # takes into account extend values:
# --> 438         self._process_values()
#     439         # sets self.vmin and vmax in data units, but just for
#     440         # the part of the colorbar that is not part of the extend
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colorbar.py in _process_values(self, b)
#     842                 self.norm.vmin,
#     843                 self.norm.vmax,
# --> 844                 expander=0.1)
#     845
#     846             b = self.norm.inverse(self._uniform_y(self.cmap.N + 1))
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/transforms.py in nonsingular(vmin, vmax, expander, tiny, increasing)
#    2891
#    2892     swapped = False
# -> 2893     if vmax < vmin:
#    2894         vmin, vmax = vmax, vmin
#    2895         swapped = True
#
# TypeError: '<' not supported between instances of 'complex' and 'complex'
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f97906b62f0> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#    1917                 offsets = np.column_stack([xs, ys])
#    1918
# -> 1919         self.update_scalarmappable()
#    1920
#    1921         if not transform.is_affine:
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/collections.py in update_scalarmappable(self)
#     777             return
#     778         if self._is_filled:
# --> 779             self._facecolors = self.to_rgba(self._A, self._alpha)
#     780         elif self._is_stroked:
#     781             self._edgecolors = self.to_rgba(self._A, self._alpha)
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     287         if norm:
#     288             x = self.norm(x)
# --> 289         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     290         return rgba
#     291
#
# ~/anaconda3/envs/pf/lib/python3.6/site-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     545
#     546         rgba = np.empty(shape=xa.shape + (4,), dtype=lut.dtype)
# --> 547         lut.take(xa, axis=0, mode='clip', out=rgba)
#     548         if vtype == 'scalar':
#     549             rgba = tuple(rgba[0, :])
#
# TypeError: Cannot cast array data from dtype('complex128') to dtype('int64') according to the rule 'safe'
